# %%
import pandas as pd 

import json

import numpy as np


from sqlalchemy import create_engine
import psycopg2

from config import db_password

import time

# %%
Data = "cleaned_billboard_df.csv"

# %%
billboard_df = pd.read_csv(Data)
billboard_df
# Out:
#       Unnamed: 0                      name                       artists  \
# 0              0             Old Town Road                      Lil Nas,
# 1              1                  Senorita  Shawn Mendes, Camila Cabello
# 2              2                   Bad Guy                 Billie Eilish
# 3              3                      Talk                        Khalid
# 4              4              I Don't Care     Ed Sheeran, Justin Bieber
# ...          ...                       ...                           ...
# 6453       97122                Praise You                   Fatboy Slim
# 6454       97124               Anyone Else                   Collin Raye
# 6455       97125                      Nann                   Trick Daddy
# 6456       97211        She's Always Right                   Clay Walker
# 6457       97224  Why Don't You Get A Job?                 The Offspring
#
#       peak_position  weeks_on_chart     week       date  \
# ...

# %%
new_billboard_df = billboard_df.drop(["Unnamed: 0"],axis=1)
new_billboard_df
# Out:
#                           name                       artists  peak_position  \
# 0                Old Town Road                      Lil Nas,            1.0
# 1                     Senorita  Shawn Mendes, Camila Cabello            NaN
# 2                      Bad Guy                 Billie Eilish            2.0
# 3                         Talk                        Khalid            3.0
# 4                 I Don't Care     Ed Sheeran, Justin Bieber            2.0
# ...                        ...                           ...            ...
# 6453                Praise You                   Fatboy Slim           36.0
# 6454               Anyone Else                   Collin Raye           37.0
# 6455                      Nann                   Trick Daddy           62.0
# 6456        She's Always Right                   Clay Walker           74.0
# 6457  Why Don't You Get A Job?                 The Offspring           74.0
#
#       weeks_on_chart     week       date  \
# ...

# %%
    db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/final_project"
    engine = create_engine(db_string)
    new_billboard_df.to_sql(name='billboard', con=engine, if_exists='replace')

# %%
Data2 = "grammy_wins.csv"

# %%
grammy_df = pd.read_csv(Data2)
grammy_df
# Out:
#                           Name  GrammyAward
# 0     'Til Summer Comes Around            1
# 1                    24 Frames            1
# 2                    24k Magic            1
# 3               500 Miles High            1
# 4                  99 Problems            1
# ..                         ...          ...
# 357     you Don't Know My Name            1
# 358                 you Got Me            1
# 359                    you Say            1
# 360         you Want it Darker            1
# 361  your Body is a Wonderland            1
#
# [362 rows x 2 columns]

# %%
    db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/final_project"
    engine = create_engine(db_string)
    grammy_df.to_sql(name='grammy', con=engine, if_exists='replace')

# %%
Data3 = "grammy_genre.csv"

# %%
grammy_genre_df = pd.read_csv(Data3)
grammy_genre_df
# Out:
#      Unnamed: 0  GrammyYear                   Genre  \
# 0             0        2018                 General
# 1             1        2018                 General
# 2             2        2018                     Pop
# 3             3        2018                     Pop
# 4             4        2018  Dance/Electronic Music
# ..          ...         ...                     ...
# 423         423        1999                     Rap
# 424         424        1999                     Rap
# 425         425        1999                 Country
# 426         426        1999                 Country
# 427         427        1999                 Country
#
#                                           Name
# 0                              this is America
# 1                              this is America
# 2    Joanne (where Do you Think You're Goin'?)
# 3                                      Shallow
# 4                                  Electricity
# ..                                         ...
# ...

# %%
    db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/final_project"
    engine = create_engine(db_string)
    grammy_genre_df.to_sql(name='grammy_genre', con=engine, if_exists='replace')
